# %%
import pickle
import pandas as pd
import plotly.offline as pyo
import plotly.express as px
import dimensionality_reduction
import json 
import random
from numpy import dot
from numpy.linalg import norm
import numpy as np
from utils import aggregate_embeddings, cosine_similarity, print_similarity_samples, replace_nan_with, load_model, load_big_consulting_export, split_into_list
from utils import load_ai_news
from tqdm import tqdm

tqdm.pandas()

# %%
def label_data(df):
    data_list = []
    for index, row in tqdm(df.iterrows()):
        context = row['snippet']

        qas_list = []

        def get_qas_item(question, company):
            answer_found = False
            if company is None:
                return {
                    'id': str(index).zfill(5),
                    'is_impossible': True,
                    'question': question,
                    'answers': []
                }
            company_words = company.split()

            for i in range(len(company_words), 0, -1):
                company_part = ' '.join(company_words[:i])
                if company_part in context:
                    answer_found = True
                    answer_text = company_part
        #             answer_start = context.find(answer_text)
                    break

            if not answer_found:
                answer_text = company_words[0]
            answer_start = context.find(answer_text)

            qas_item = {
                'id': str(index).zfill(5),
                'is_impossible': False,
                'question': question,
                'answers': [{
                    'text': answer_text,
                    'answer_start': answer_start
                }]
            }


            return qas_item

        # If 'relationEntityType' is 'company', remove the value in 'relationEntity'
        df.at[index, 'relationEntity'] = None


        qas_item = get_qas_item("What is the company's name?", row['company'])
        if row['relationEntityType'] == 'company' and not pd.isnull(row['relationEntity']):
            qas_item_2 = get_qas_item("What is the other company's name?", row['relationEntity'])
        else:
            qas_item_2 = get_qas_item("What is the other company's name?", None)
        qas_list.append(qas_item)
        qas_list.append(qas_item_2)

        data_item = {
            'context': context,
            'qas': qas_list
        }

        data_list.append(data_item)
    return data_list

big_consulting_df = load_big_consulting_export()
data_list = label_data(big_consulting_df)
data_list[:10]
# Out:
# 12063it [00:00, 34767.50it/s]
# [{'context': 'at KPMG where he focused on complex financial matters and financial trading, investment banking and lending businesses',
#   'qas': [{'id': '00000',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'KPMG', 'answer_start': 3}]},
#    {'id': '00000',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'LatentView has been recognized as an industry leader by Gartner',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'Gartner', 'answer_start': 56}]},
#    {'id': '00001',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'In his last role, Prashant was playing the role of Portfolio & Regional Head at Infosys, as a key leader for their Communications, Media and Entertainment business',
#   'qas': [{'id': '00002',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'Infosys', 'answer_start': 80}]},
#    {'id': '00002',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'We\'re proud of the end result of this implementation and congratulate our valued client for this award," said Richard Palmer, Senior Managing Director within the Technology segment at FTI Consulting',
#   'qas': [{'id': '00003',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'Fti', 'answer_start': -1}]},
#    {'id': '00003',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'Wipro consolidates presence in foods with acquisition of Kerala-based Brahmins',
#   'qas': [{'id': '00004',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'Wipro', 'answer_start': 0}]},
#    {'id': '00004',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'Days after reports claimed that Tata Consultancy Services might roll out 100 per cent variable payout for a section of employees for the recent quarter, another IT services exporter HCLTech announced that 85 per cent',
#   'qas': [{'id': '00005',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'Tata Consultancy Services', 'answer_start': 32}]},
#    {'id': '00005',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'messenger RNA (mRNA) therapeutics and vaccines, and IBM announced an agreement under which Moderna will explore next generation technologies including quantum computing and artificial intelligence to advance and accelerate mRNA research and science',
#   'qas': [{'id': '00006',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'IBM', 'answer_start': 52}]},
#    {'id': '00006',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': 'Under the agreement, IBM will provide access to quantum computing systems',
#   'qas': [{'id': '00007',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'IBM', 'answer_start': 21}]},
#    {'id': '00007',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': "IBM's purpose is to be the catalyst",
#   'qas': [{'id': '00008',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'IBM', 'answer_start': 0}]},
#    {'id': '00008',
#     'is_impossible': True,
#     'question': "What is the other company's name?",
#     'answers': []}]},
#  {'context': "Moderna and IBM scientists will apply MoLFormer, an AI foundation model that can help scientists predict a molecule's properties, and could help them understand the characteristics of potential mRNA medicines",
#   'qas': [{'id': '00009',
#     'is_impossible': False,
#     'question': "What is the company's name?",
#     'answers': [{'text': 'IBM', 'answer_start': 12}]},
#    {'id': '00009',
#     'is_impossible': False,
#     'question': "What is the other company's name?",
#     'answers': [{'text': 'Moderna', 'answer_start': 0}]}]}]

# %%
random.seed(42)
random.shuffle(data_list)
test_data = data_list[:100]
val_data = data_list[100:200]
train_data = data_list[200:]

# %%
import json
import logging
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs
 
model_type="bert"
model_name= "bert-base-cased"
 
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
#     "output_dir": f"outputs/{model_type}",
#     "best_model_dir": f"{output_dir}/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 2,
    "evaluate_during_training_steps": 100,
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":8,
    "train_batch_size": 16,
    "eval_batch_size": 16
}
model = QuestionAnsweringModel(model_type,model_name, args=train_args, use_cuda=False)
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# https://thinkinfi.com/fine-tune-bert-for-question-answering/
model.train_model(train_data, eval_data=test_data)
result, texts = model.eval_model(test_data)
# Out:
# convert squad examples to features:   0%|                                     | 0/23726 [00:00<?, ?it/s]Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fnts'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: 'reference' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fy'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: 'Nigeria' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ppg'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'Coal'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'TATA'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Bharat'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Borges'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'Ing'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'VISTRA'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Nasa'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Citibank'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Reliance'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Edii'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'mphasis'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ltimindtree'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Santander'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Nasa'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Oneamerica'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'South'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'cK-renA'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Small'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'TopCoder'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'DFPG'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Reaqta'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Hp&E'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fyld'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Everc'
# Could not find answer: '' vs. 'Xjera'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fy'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Singapore'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Pcep'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. '41st'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Auditclub'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'LW'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Bnp'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AUS'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'mphasis'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tarc'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Small'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: 'audit' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Cognisure'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Applied'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Altibase'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'FTI'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'GupShup'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'GlobalFoundries'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Enterprises'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Hcltech'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Middle'
# Could not find answer: '' vs. 'Cognizant'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Stepzen'
# Could not find answer: '' vs. 'Stepzen'
# Could not find answer: '' vs. 'Bharat'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Mary's'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'FTI'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'RiSE'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Xjera'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ey'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Omron'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'iDC'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'LW'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Telecom'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Atamis'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fy'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tesla'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'MindSpark,'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Weather.com'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'L.e.K.'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'KAO'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Commonwealth'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tarc'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Netnut'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'CoverHound'
# Could not find answer: '' vs. 'Linuxone'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'SAS-ALC'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Infosys'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Liberty'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Cohesity,'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Huron'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Vaiot'
# Could not find answer: '' vs. 'Capgemini'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ns1'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Lubepm'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'StockNewsNow.com'
# Could not find answer: '' vs. 'mphasis'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tcs'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Deloitte'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Accenture'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Perfect'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Hcltech'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fy'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'Skyoak'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Revenue'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'AXA'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'GupShup'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'ANT'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'FTI'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Cognizant'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Bain'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# ...
# Could not find answer: '' vs. 'Pcep'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Dae'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Eet'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Cognisure'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Cohesity,'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'JPMorgan'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Security'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'SAN'
# Could not find answer: '' vs. 'HCL'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Xjera'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Wilmington'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Xceed'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'mphasis'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Willis'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ing'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Olay'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ns1'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Sfu'
# Could not find answer: '' vs. 'Gartner'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Sxiq'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Beis'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'DirectLink'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'E&Y'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Booz'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Ultratech'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'Ns1'
# Could not find answer: '' vs. 'Wipro'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'TATA'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Conway'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'SAN'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Globalfoundries'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: 'actyv.ai' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'I-Tech'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'America'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Ernst'
# convert squad examples to features:  67%|███████████████▎       | 15817/23726 [00:04<00:01, 5036.18it/s]Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'AlixPartners'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Global'
# Could not find answer: '' vs. 'Fti'
# Could not find answer: '' vs. 'Ernst'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Tata'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'Aon'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# Could not find answer: '' vs. 'IBM'
# Could not find answer: '' vs. 'PricewaterhouseCoopers'
# convert squad examples to features: 100%|███████████████████████| 23726/23726 [00:04<00:00, 5661.09it/s]
# add example index and unique id: 100%|███████████████████████| 23726/23726 [00:00<00:00, 1884200.64it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 0 of 2:   0%|          | 0/1336 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Epoch 1 of 2:   0%|          | 0/1336 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
result, texts
# Out:
# ({'correct': 87,
#   'similar': 12,
#   'incorrect': 1,
#   'eval_loss': -7.92989103610699},
#  {'correct_text': {'04165': '',
#    '05680': '',
#    '08171': '',
#    '07163': '',
#    '05207': '',
#    '13343': '',
#    '10926': '',
#    '11356': '',
#    '10008': '',
#    '11150': '',
#    '02421': '',
#    '13115': '',
#    '06551': '',
#    '09305': '',
#    '06138': '',
#    '01814': '',
#    '11872': '',
#    '00196': '',
#    '11553': '',
#    '05293': '',
#    '08185': '',
#    '04640': '',
#    '13350': '',
#    '07424': '',
#    '08832': '',
#    '00238': '',
#    '10940': '',
#    '04952': '',
#    '07046': 'Threadgill Financial LLC',
#    '10653': '',
#    '04653': '',
#    '09520': '',
#    '07879': '',
#    '12744': '',
#    '03979': '',
#    '04821': '',
#    '11664': '',
#    '06939': '',
#    '09433': '',
#    '01889': '',
#    '08702': '',
#    '03244': '',
#    '11501': '',
#    '09493': '',
#    '11981': '',
#    '10096': '',
#    '11574': '',
#    '04968': '',
#    '12465': '',
#    '11021': '',
#    '12859': '',
#    '09284': '',
#    '01905': '',
#    '07100': '',
#    '02122': '',
#    '11141': '',
#    '09968': '',
#    '13082': '',
#    '11044': '',
#    '11181': '',
#    '01815': '',
#    '03970': '',
#    '11687': '',
#    '04519': '',
#    '00501': 'Sangfor Technologies',
#    '00867': '',
#    '05887': '',
#    '10683': '',
#    '05284': 'Balentine LLC',
#    '05964': '',
#    '07014': '',
#    '03824': 'TCS',
#    '11611': 'McKinsey',
#    '01400': '',
#    '03665': '',
#    '06815': '',
#    '08135': '',
#    '04163': '',
#    '13357': '',
#    '05162': 'TCS',
#    '12300': '',
#    '11582': '',
#    '09652': '',
#    '08147': '',
#    '09089': '',
#    '04116': '',
#    '12360': ''},
#   'similar_text': {'03741': {'truth': '',
#     'predicted': 'Watson Health',
#     'question': "What is the other company's name?"},
#    '12660': {'truth': 'TCS',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '03126': {'truth': 'Ltimindtree',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '01798': {'truth': 'GlobalFoundries',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '12930': {'truth': 'Gartner',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '01555': {'truth': 'GlobalFoundries',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '11402': {'truth': 'QPR Software',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '12583': {'truth': 'E&Y',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '05274': {'truth': '',
#     'predicted': 'Trusteer',
#     'question': "What is the other company's name?"},
#    '02473': {'truth': 'Reinsurance Solutions',
#     'predicted': '',
#     'question': "What is the other company's name?"},
#    '06255': {'truth': '',
#     'predicted': 'Berger Paints',
#     'question': "What is the other company's name?"},
#    '02671': {'truth': 'Bain',
#     'predicted': '',
#     'question': "What is the other company's name?"}},
#   'incorrect_text': {'02415': {'truth': 'Tata',
#     'predicted': 'TCS',
#     'question': "What is the other company's name?"}}})

# %%
def get_inference_data(df):
    data_list = []
    for index, row in tqdm(df.iterrows()):
        context = row['snippet']

        qas_list = []

        def get_qas_inference_item(question):

            qas_item = {
                'id': str(index).zfill(5),
                'question': question,
            }

            return qas_item

        qas_item = get_qas_inference_item("What is the company's name?")
        qas_item_2 = get_qas_inference_item("What is the other company's name?")
        qas_list.append(qas_item)
        qas_list.append(qas_item_2)

        data_item = {
            'context': context,
            'qas': qas_list
        }

        data_list.append(data_item)
    return data_list

news_df = load_ai_news()
inference_data = get_inference_data(news_df)
inference_data[:10]
# Out:
# 262523it [00:06, 40508.87it/s]
# [{'context': '( Get Free Report CS Disco, Inc provides cloud-native and 1-powered legal solutions for ediscovery, legal document review, and case management for enterprises, law firms, legal services providers, and governments.',
#   'qas': [{'id': '00000', 'question': "What is the company's name?"},
#    {'id': '00000', 'question': "What is the other company's name?"}]},
#  {'context': 'Some additional features SoMee offers include an 1 platform that offers 1 services for voiceovers, images, c',
#   'qas': [{'id': '00001', 'question': "What is the company's name?"},
#    {'id': '00001', 'question': "What is the other company's name?"}]},
#  {'context': 'Exscientia plc, an 1-driven pharmatech company, engages in discovering, designing, and developing drugs.',
#   'qas': [{'id': '00002', 'question': "What is the company's name?"},
#    {'id': '00002', 'question': "What is the other company's name?"}]},
#  {'context': "But what allows CrowdStrike to stand apart from its peers is Falcon , the company's cloud-native, 1 (1)-driven cybersecurity platform.",
#   'qas': [{'id': '00003', 'question': "What is the company's name?"},
#    {'id': '00003', 'question': "What is the other company's name?"}]},
#  {'context': 'Google is at the top of the pack in the 1 race, and everything they are working on is high valu',
#   'qas': [{'id': '00004', 'question': "What is the company's name?"},
#    {'id': '00004', 'question': "What is the other company's name?"}]},
#  {'context': 'July 22nd, 2023 ( Zolmax.com — Delivered by Newstex ) C3.1, Inc. ( NYSE:1 - Get Free Report ) saw a significant increase in short interest in the month of June.',
#   'qas': [{'id': '00005', 'question': "What is the company's name?"},
#    {'id': '00005', 'question': "What is the other company's name?"}]},
#  {'context': 'BlackRock Inc. lifted its position in shares of C3.1 by 3.8% during the 3rd quarter.',
#   'qas': [{'id': '00006', 'question': "What is the company's name?"},
#    {'id': '00006', 'question': "What is the other company's name?"}]},
#  {'context': 'C3.1 ( NYSE:1 - Get Free Report ) last released its earnings results on Wednesday, May 31st.',
#   'qas': [{'id': '00007', 'question': "What is the company's name?"},
#    {'id': '00007', 'question': "What is the other company's name?"}]},
#  {'context': 'C3.1 had a negative return on equity of 28.23% and a negative net margin of 100.77%.',
#   'qas': [{'id': '00008', 'question': "What is the company's name?"},
#    {'id': '00008', 'question': "What is the other company's name?"}]},
#  {'context': 'Analysts predict that C3.1 will post -2.14 EPS for t',
#   'qas': [{'id': '00009', 'question': "What is the company's name?"},
#    {'id': '00009', 'question': "What is the other company's name?"}]}]

# %%
# Load model from training checkpoint
# from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# model = QuestionAnsweringModel("bert", "outputs/bert/best_model")


# Make predictions with the model
to_predict = [
    {
        "context": "Samsung Galaxy M14 5G (Smoky Teal, 6GB, 128GB Storage) | 50MP Triple Cam | 6000 mAh Battery | 5nm Octa-Core Processor | 12GB RAM with RAM Plus | Android 13 | Without Charger",
        "qas": [
            {
                "question": "What is the model name of the Samsung smartphone?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(inference_data, n_best_size=None)
print(answers[:10])
# Run at night
# Out:
# convert squad examples to features: 100%|█████████████████████| 525046/525046 [01:55<00:00, 4549.81it/s]
# add example index and unique id: 100%|█████████████████████| 525046/525046 [00:00<00:00, 1604751.83it/s]
# Running Prediction:   0%|          | 0/32892 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#       1 # Load model from training checkpoint
#       2 # from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs
#       3
#    (...)
#       6
#       7 # Make predictions with the model
#       8 to_predict = [
#       9     {
#      10         "context": "Samsung Galaxy M14 5G (Smoky Teal, 6GB, 128GB Storage) | 50MP Triple Cam | 6000 mAh Battery | 5nm Octa-Core Processor | 12GB RAM with RAM Plus | Android 13 | Without Charger",
#    (...)
#      17     }
#      18 ]
# ---> 20 answers, probabilities = model.predict(inference_data, n_best_size=None)
#      21 print(answers[:10])
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/simpletransformers/question_answering/question_answering_model.py:1351, in QuestionAnsweringModel.predict(self, to_predict, n_best_size)
#    1349         outputs = model(**inputs)
#    1350 else:
# -> 1351     outputs = model(**inputs)
#    1353 for i, example_index in enumerate(example_indices):
#    1354     eval_feature = features[example_index.item()]
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1844, in BertForQuestionAnswering.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1832 r"""
#    1833 start_positions (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1834     Labels for position (index) of the start of the labelled span for computing the token classification loss.
#    (...)
#    1840     are not taken into account for computing the loss.
#    1841 """
#    1842 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1844 outputs = self.bert(
#    1845     input_ids,
#    1846     attention_mask=attention_mask,
#    1847     token_type_ids=token_type_ids,
#    1848     position_ids=position_ids,
#    1849     head_mask=head_mask,
#    1850     inputs_embeds=inputs_embeds,
#    1851     output_attentions=output_attentions,
#    1852     output_hidden_states=output_hidden_states,
#    1853     return_dict=return_dict,
#    1854 )
#    1856 sequence_output = outputs[0]
#    1858 logits = self.qa_outputs(sequence_output)
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1022, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1013 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1015 embedding_output = self.embeddings(
#    1016     input_ids=input_ids,
#    1017     position_ids=position_ids,
#    (...)
#    1020     past_key_values_length=past_key_values_length,
#    1021 )
# -> 1022 encoder_outputs = self.encoder(
#    1023     embedding_output,
#    1024     attention_mask=extended_attention_mask,
#    1025     head_mask=head_mask,
#    1026     encoder_hidden_states=encoder_hidden_states,
#    1027     encoder_attention_mask=encoder_extended_attention_mask,
#    1028     past_key_values=past_key_values,
#    1029     use_cache=use_cache,
#    1030     output_attentions=output_attentions,
#    1031     output_hidden_states=output_hidden_states,
#    1032     return_dict=return_dict,
#    1033 )
#    1034 sequence_output = encoder_outputs[0]
#    1035 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:612, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     603     layer_outputs = torch.utils.checkpoint.checkpoint(
#     604         create_custom_forward(layer_module),
#     605         hidden_states,
#    (...)
#     609         encoder_attention_mask,
#     610     )
#     611 else:
# --> 612     layer_outputs = layer_module(
#     613         hidden_states,
#     614         attention_mask,
#     615         layer_head_mask,
#     616         encoder_hidden_states,
#     617         encoder_attention_mask,
#     618         past_key_value,
#     619         output_attentions,
#     620     )
#     622 hidden_states = layer_outputs[0]
#     623 if use_cache:
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:497, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     485 def forward(
#     486     self,
#     487     hidden_states: torch.Tensor,
#    (...)
#     494 ) -> Tuple[torch.Tensor]:
#     495     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     496     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 497     self_attention_outputs = self.attention(
#     498         hidden_states,
#     499         attention_mask,
#     500         head_mask,
#     501         output_attentions=output_attentions,
#     502         past_key_value=self_attn_past_key_value,
#     503     )
#     504     attention_output = self_attention_outputs[0]
#     506     # if decoder, the last output is tuple of self-attn cache
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:427, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     417 def forward(
#     418     self,
#     419     hidden_states: torch.Tensor,
#    (...)
#     425     output_attentions: Optional[bool] = False,
#     426 ) -> Tuple[torch.Tensor]:
# --> 427     self_outputs = self.self(
#     428         hidden_states,
#     429         attention_mask,
#     430         head_mask,
#     431         encoder_hidden_states,
#     432         encoder_attention_mask,
#     433         past_key_value,
#     434         output_attentions,
#     435     )
#     436     attention_output = self.output(self_outputs[0], hidden_states)
#     437     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:309, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     307 else:
#     308     key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 309     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     311 query_layer = self.transpose_for_scores(mixed_query_layer)
#     313 use_cache = past_key_value is not None
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/ml/lib/python3.9/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# Read the original file
input_file_path = '../glanos-data/clustering/big_consulting_export_replace.tsv'
df = pd.read_csv(input_file_path, sep='\t')

# Drop duplicates based on the 'replace' column
df_no_duplicates = df.drop_duplicates(subset='replace')

# Save the DataFrame to a new file
output_file_path = '../glanos-data/clustering/big_consulting_export_replace_no_duplicates.tsv'
df_no_duplicates.to_csv(output_file_path, sep='\t', index=False)
